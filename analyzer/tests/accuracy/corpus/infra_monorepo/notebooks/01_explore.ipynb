# %% [markdown]
# # Dataset exploration
#
# Run order in this notebook is **not** top to bottom: cell 4 was re-run after cell 6.

# %%
# !pip install -q seaborn
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "..")

import numpy as np
import pandas as pd
import seaborn as sns
import torch

from libs.vision.data import eval_transform, train_transform

# %%
frame = pd.read_csv("../data/manifest.csv")
frame.head()

# %%
# %%time
counts = frame["label"].value_counts()
sns.barplot(x=counts.index, y=counts.values)

# %%
transform = train_transform(224)
print([type(t).__name__ for t in transform.transforms])

# %%
print(eval_transform(224))
print(torch.__version__, np.__version__)
