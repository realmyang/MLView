# %% [markdown]
# # Hand-off notes
#
# Markdown only, plus one cell that writes the metrics file. Nothing here
# is ML and MLView must not invent a stage for it.

# %%
import json
from pathlib import Path

Path("artifacts").mkdir(exist_ok=True)
Path("artifacts/handoff.json").write_text(json.dumps({
    "owner": "support-ml",
    "runbook": "docs/runbook.md",
}))

# %% [markdown]
# ## Open questions
#
# 1. Should the router fall back to the keyword rules under low confidence?
# 2. Who owns the retraining cadence?
