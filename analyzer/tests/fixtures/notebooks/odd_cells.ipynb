# %% [markdown]
# # Title

# %%
# %%bash
# echo "this cell is not python"
# for f in *.csv; do echo $f; done

# %%
x = 1
y = x + 1

# %%
QUERY = """
select *
from t
where pct % 2 = 0
"""
total = (10
         % 3)
scaler_note = "!not a shell escape"

# %%
np.load?
# %time y = 1
