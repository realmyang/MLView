# %% [markdown]
# ROB-05. The install cell is a shell escape whose command is spread over
# three source lines with backslash continuations - the single commonest
# shape in a public Colab notebook. The converter blanks the first line and
# leaves the two indented continuations as Python, so the generated module
# raises IndentationError and the whole notebook is skipped, taking the
# training loop two cells below it with it.

# %%
# !pip install -q \
    torch \
    torchvision

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
features = torch.randn(64, 16)
labels = torch.randint(0, 3, (64,))
ds = TensorDataset(features, labels)
loader = DataLoader(ds, batch_size=8, shuffle=True)

# %%
model = nn.Linear(16, 3)
opt = torch.optim.Adam(model.parameters(), lr=1e-3)
crit = nn.CrossEntropyLoss()
for xb, yb in loader:
    opt.zero_grad()
    loss = crit(model(xb), yb)
    loss.backward()
    opt.step()
